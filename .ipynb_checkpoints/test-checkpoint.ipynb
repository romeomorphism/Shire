# %%
# %load_ext autoreload
# %autoreload 2

# %%
import shire as sh
import numpy as np

# %%
images = sh.ImageSeries(path="../../GitHub_Data/Particle_Tracking/bdnf rfp 600ap 3mW.tif")

# %%
images.shape
# Out:
# (1600, 512, 512)

# %%
cimages.crop([256, 256], 200, 200, illustrate=True)
